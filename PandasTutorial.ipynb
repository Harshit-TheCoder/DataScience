# %%
import pandas as pd

# %%
s = pd.Series([10,20,30], index=["a", "b", "c"])
df = pd.DataFrame({
    'Name': ['Alice', 'Bob', 'Charlie'],
    'Age': [25, 30, 35],
    'City': ['Delhi', 'Mumbai', 'Chennai']
})

# %%
# df = pd.read_csv('data.csv')
# df.to_excel('data.xlsx', index=False)

# %%
df.head()
# Out:
#       Name  Age     City
# 0    Alice   25    Delhi
# 1      Bob   30   Mumbai
# 2  Charlie   35  Chennai

# %%
df.tail()
# Out:
#       Name  Age     City
# 0    Alice   25    Delhi
# 1      Bob   30   Mumbai
# 2  Charlie   35  Chennai

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    3 non-null      object
#  1   Age     3 non-null      int64
#  2   City    3 non-null      object
# dtypes: int64(1), object(2)
# memory usage: 204.0+ bytes

# %%
df.describe()
# Out:
#         Age
# count   3.0
# mean   30.0
# std     5.0
# min    25.0
# 25%    27.5
# 50%    30.0
# 75%    32.5
# max    35.0

# %%
df['Name']
# Out:
# 0      Alice
# 1        Bob
# 2    Charlie
# Name: Name, dtype: object

# %%
df[['Name', 'City']]
# Out:
#       Name     City
# 0    Alice    Delhi
# 1      Bob   Mumbai
# 2  Charlie  Chennai

# %%
df.iloc[0:2]
# Out:
#     Name  Age    City
# 0  Alice   25   Delhi
# 1    Bob   30  Mumbai

# %%
df.loc[0:2, 'Name']
# Out:
# 0      Alice
# 1        Bob
# 2    Charlie
# Name: Name, dtype: object

# %%
print(df[df['Age'] > 28])
print(df[(df['Age'] > 28) & (df['City'] == 'Delhi')])
# Out:
#       Name  Age     City
# 1      Bob   30   Mumbai
# 2  Charlie   35  Chennai
# Empty DataFrame
# Columns: [Name, Age, City]
# Index: []

# %%
df.sort_values(by='Age', ascending=False)
# Out:
#       Name  Age     City
# 2  Charlie   35  Chennai
# 1      Bob   30   Mumbai
# 0    Alice   25    Delhi

# %%
df.groupby('City')['Age'].mean()
# Out:
# City
# Chennai    35.0
# Delhi      25.0
# Mumbai     30.0
# Name: Age, dtype: float64

# %% [markdown]
# df.dropna(

# %%
df.dropna()
df.fillna(0)
# Out:
#       Name  Age     City
# 0    Alice   25    Delhi
# 1      Bob   30   Mumbai
# 2  Charlie   35  Chennai

# %%
df['Salary'] = df['Age'] * 1000

# %%
df
# Out:
#       Name  Age     City  Salary
# 0    Alice   25    Delhi   25000
# 1      Bob   30   Mumbai   30000
# 2  Charlie   35  Chennai   35000

# %%
df1 = pd.DataFrame({
    'ID': [1,2,3],
    'Name': ['Alice', 'Bob', 'Charlie'],
    'Age': [25, 30, 35],
    'City': ['Delhi', 'Mumbai', 'Chennai']
})
df2 = pd.DataFrame({
    'ID': [1,2,3],
    'Salary': [250000, 300000, 350000],
    'Experience': [2, 3, 5],
    'Bonus': [25000, 30000, 35000]
})

# %%
df1
# Out:
#    ID     Name  Age     City
# 0   1    Alice   25    Delhi
# 1   2      Bob   30   Mumbai
# 2   3  Charlie   35  Chennai

# %%
df2
# Out:
#    ID  Salary  Experience  Bonus
# 0   1  250000           2  25000
# 1   2  300000           3  30000
# 2   3  350000           5  35000

# %%
df3 = pd.merge(df1, df2, on='ID', how='inner')

# %%
df3
# Out:
#    ID     Name  Age     City  Salary  Experience  Bonus
# 0   1    Alice   25    Delhi  250000           2  25000
# 1   2      Bob   30   Mumbai  300000           3  30000
# 2   3  Charlie   35  Chennai  350000           5  35000

# %%
df4 = df.pivot_table(index='City', values='Age', aggfunc = 'mean')

# %%
df4
# Out:
#           Age
# City
# Chennai  35.0
# Delhi    25.0
# Mumbai   30.0

# %%
# df['Date'] = pd.to_datetime(df['Date'])
# df['Year'] = df['Date'].dt.year

# %%
df = df['Age'].apply(lambda x: x + 1)

# %%
df
# Out:
# 0    26
# 1    31
# 2    36
# Name: Age, dtype: int64
